# %% [markdown]
# # Exploring specifics related to datasets

# %%
import pandas as pd
from icecream import ic

# %%
df = pd.read_csv("mettef_vis.csv")#[1:].rename(columns={"0":"created_at", "1":"id", "2":"text", "3":"mettef", "4":"b117", "5":"wider"})
df = df.sort_values(by='created_at').reset_index(drop=True)
ic(len(df))
df.head()
# Out:
# ic| len(df): 1880
#    index                 created_at            id  \
# 0      0  2020-02-01 17:12:31+00:00  1.223655e+18
# 1      1  2020-02-02 17:20:33+00:00  1.224020e+18
# 2      2  2020-02-04 14:54:08+00:00  1.224708e+18
# 3      3  2020-02-04 22:28:03+00:00  1.224822e+18
# 4      4  2020-02-05 14:56:05+00:00  1.225071e+18
#
#                                                 text search_keyword    neg  \
# 0  #MetteF ( @Spolitik ) er KUN #statsminister FO...     ['mettef']  0.000
# 1  @Hagbard_Dane S realiserede jo en højredrejnin...     ['mettef']  0.063
# 2  https://t.co/KO6XahwCdL ... #NokerNok #IkkeIMi...     ['mettef']  0.000
# 3  @maiakm @Hagbard_Dane Måske noget for @Spoliti...     ['mettef']  0.000
# 4  https://t.co/TwurN0G2jR #NokerNok #TørDuBliveS...     ['mettef']  0.145
#
#      neu    pos  compound        date  \
# 0  1.000  0.000    0.0000  2020-02-01
# 1  0.751  0.187    0.6834  2020-02-02
# 2  1.000  0.000    0.0000  2020-02-04
# ...
